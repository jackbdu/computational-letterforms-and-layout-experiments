# %%
import random
import math

# %%
from IPython.display import display, HTML
def show_html(src):
    return display(HTML(src), metadata=dict(isolated=True))

# %%
html_template = """<!doctype html>
<html>
<head>
<meta charset="utf-8">
<title>{title}</title>
<style>
html {{ height: 32em; overflow: hidden; }}
{style}
</style>
</head>
<body>
{content}
</body>
</html>
"""

# %%
def p5_map(n, fromMin, fromMax, toMin, toMax):
    return (n - fromMin) / (fromMax - fromMin) * (toMax - toMin) + toMin

# %%
elements = []
styles = ['']
cols_num = 20
rows_num = 10
texts = '仁义道德'
hidden_texts = '吃人'
hidden_text_saturation = 3
font_family = 'monospace'
periods_num = 1
element_width = 100 / cols_num * 0.95
element_height = 100 / rows_num * 0.95
font_size = '2em'

for c in range(cols_num):
    for r in range(rows_num):
        class_name = f'text_{c}_{r}'
        
        x = p5_map(c, 0, cols_num-1, element_width/2, 100-element_width/2)
        y = p5_map(r, 0, rows_num-1, element_height/2, 100-element_height/2)

        hover_turn = p5_map(random.random(), 0, 1, -0.3, 0.3)
        hover_offset_x = p5_map(random.random(), 0, 1, -150, 50)
        hover_offset_y = p5_map(random.random(), 0, 1, -150, 50)
        
        text = random.choice(texts)
        
        element = f"<button class='{class_name}'>{text}</button>"
        
        shared_style_properties = f"""
        width: {element_width}%;
        height: {element_height}%;
        position: absolute;
        left: {x}%;
        top: {y}%;
        font-family: {font_family};
        font-size: {font_size};
        """
        
        style = f"""
        .{class_name} {{
        {shared_style_properties}
        transform: translate(-50%, -50%);
        transition: all 1s;
        }}

        .{class_name}:hover {{
        transform: translate({hover_offset_x}%, {hover_offset_y}%) rotate({hover_turn}turn);
        }}
        """
        
        elements.append(element)
        styles.append(style)

        for i in range(hidden_text_saturation):
            hidden_text_class_name = f'hidden_text_{c}_{r}_{i}'
            hidden_text = random.choice(hidden_texts)
            
            hidden_text_element = f"<p class='{hidden_text_class_name}'>{hidden_text}</p>"
    
            hidden_text_offset_x = p5_map(random.random(), 0, 1, -100, 0)
            hidden_text_offset_y = p5_map(random.random(), 0, 1, -100, 0)
            
            hidden_text_style = f"""
            .{hidden_text_class_name} {{
            {shared_style_properties}
            transform: translate({hidden_text_offset_x}%, {hidden_text_offset_y}%);
            text-align: center;
            color: #d04;
            z-index: -1;
            }}
            """
        
            elements.append(hidden_text_element)
            styles.append(hidden_text_style)
        
html_src = html_template.format(title="Why", content="".join(elements), style="".join(styles))

show_html(html_src)
# Out:
# <!doctype html>
# <html>
# <head>
# <meta charset="utf-8">
# <title>Why</title>
# <style>
# html { height: 32em; overflow: hidden; }
#
#         .text_0_0 {
#
#         width: 4.75%;
#         height: 9.5%;
#         position: absolute;
#         left: 2.375%;
#         top: 4.75%;
#         font-family: monospace;
#         font-size: 2em;
#
#         transform: translate(-50%, -50%);
#         transition: all 1s;
#         }
#
#         .text_0_0:hover {
#         transform: translate(-45.977956415059424%, -44.02579922916627%) rotate(-0.13163524884268965turn);
#         }
#
#             .hidden_text_0_0_0 {
#
#         width: 4.75%;
#         height: 9.5%;
#         position: absolute;
#         left: 2.375%;
#         top: 4.75%;
#         font-family: monospace;
#         font-size: 2em;
#
#             transform: translate(-97.90158840344671%, -86.53537515726809%);
#             text-align: center;
#             color: #d04;
#             z-index: -1;
#             }
#
#             .hidden_text_0_0_1 {
#
#         width: 4.75%;
#         height: 9.5%;
#         position: absolute;
#         left: 2.375%;
#         top: 4.75%;
#         font-family: monospace;
#         font-size: 2em;
#
#             transform: translate(-83.10092182036993%, -15.969268954193112%);
#             text-align: center;
#             color: #d04;
#             z-index: -1;
#             }
#
#             .hidden_text_0_0_2 {
#
#         width: 4.75%;
#         height: 9.5%;
#         position: absolute;
#         left: 2.375%;
#         top: 4.75%;
#         font-family: monospace;
#         font-size: 2em;
#
#             transform: translate(-62.0195967225471%, -12.9661606047556%);
#             text-align: center;
#             color: #d04;
#             z-index: -1;
#             }
#
#         .text_0_1 {
#
#         width: 4.75%;
#         height: 9.5%;
#         position: absolute;
#         left: 2.375%;
#         top: 14.805555555555555%;
#         font-family: monospace;
#         font-size: 2em;
#
#         transform: translate(-50%, -50%);
#         transition: all 1s;
#         }
#
#         .text_0_1:hover {
#         transform: translate(17.91761441722872%, 6.992818885990317%) rotate(-0.1264606724643265turn);
#         }
#
#             .hidden_text_0_1_0 {
#
#         width: 4.75%;
#         height: 9.5%;
#         position: absolute;
#         left: 2.375%;
#         top: 14.805555555555555%;
#         font-family: monospace;
#         font-size: 2em;
#
#             transform: translate(-26.38428875415339%, -52.51005201963586%);
#             text-align: center;
#             color: #d04;
#             z-index: -1;
#             }
#
#             .hidden_text_0_1_1 {
#
#         width: 4.75%;
#         height: 9.5%;
#         position: absolute;
#         left: 2.375%;
#         top: 14.805555555555555%;
#         font-family: monospace;
#         font-size: 2em;
#
#             transform: translate(-85.52626872914371%, -16.459684739871264%);
#             text-align: center;
#             color: #d04;
#             z-index: -1;
#             }
#
#             .hidden_text_0_1_2 {
#
#         width: 4.75%;
#         height: 9.5%;
#         position: absolute;
#         left: 2.375%;
#         top: 14.805555555555555%;
#         font-family: monospace;
#         font-size: 2em;
#
#             transform: translate(-81.10796886077868%, -65.82362525312504%);
#             text-align: center;
#             color: #d04;
#             z-index: -1;
#             }
#
#         .text_0_2 {
#
#         width: 4.75%;
#         height: 9.5%;
#         position: absolute;
#         left: 2.375%;
#         top: 24.86111111111111%;
#         font-family: monospace;
#         font-size: 2em;
#
#         transform: translate(-50%, -50%);
#         transition: all 1s;
#         }
#
#         .text_0_2:hover {
#         transform: translate(-86.3965305443534%, -62.74087463767286%) rotate(-0.2825447878961117turn);
#         }
#
#             .hidden_text_0_2_0 {
#
#         width: 4.75%;
#         height: 9.5%;
#         position: absolute;
#         left: 2.375%;
#         top: 24.86111111111111%;
#         font-family: monospace;
#         font-size: 2em;
#
#             transform: translate(-41.14027505779111%, -6.013924051625835%);
#             text-align: center;
#             color: #d04;
#             z-index: -1;
#             }
#
#             .hidden_text_0_2_1 {
#
#         width: 4.75%;
#         height: 9.5%;
#         position: absolute;
#         left: 2.375%;
#         top: 24.86111111111111%;
#         font-family: monospace;
#         font-size: 2em;
#
#             transform: translate(-69.35168463440806%, -9.945736060645856%);
#             text-align: center;
#             color: #d04;
#             z-index: -1;
#             }
#
#             .hidden_text_0_2_2 {
#
#         width: 4.75%;
#         height: 9.5%;
#         position: absolute;
#         left: 2.375%;
#         top: 24.86111111111111%;
#         font-family: monospace;
#         font-size: 2em;
#
#             transform: translate(-57.623888133901715%, -81.12198651786908%);
#             text-align: center;
#             color: #d04;
#             z-index: -1;
#             }
#
#         .text_0_3 {
#
#         width: 4.75%;
#         height: 9.5%;
#         position: absolute;
#         left: 2.375%;
#         top: 34.916666666666664%;
#         font-family: monospace;
#         font-size: 2em;
#
#         transform: translate(-50%, -50%);
#         transition: all 1s;
#         }
#
#         .text_0_3:hover {
#         transform: translate(25.633709152844432%, -73.49315904679148%) rotate(-0.2955671921646666turn);
#         }
#
#             .hidden_text_0_3_0 {
#
#         width: 4.75%;
#         height: 9.5%;
#         position: absolute;
#         left: 2.375%;
#         top: 34.916666666666664%;
#         font-family: monospace;
#         font-size: 2em;
#
#             transform: translate(-16.06644804595777%, -27.120880123019944%);
#             text-align: center;
#             color: #d04;
#             z-index: -1;
#             }
#
#             .hidden_text_0_3_1 {
#
#         width: 4.75%;
#         height: 9.5%;
#         position: absolute;
#         left: 2.375%;
#         top: 34.916666666666664%;
#         font-family: monospace;
#         font-size: 2em;
#
#             transform: translate(-15.904847363281036%, -75.45032071455626%);
#             text-align: center;
#             color: #d04;
#             z-index: -1;
#             }
#
#             .hidden_text_0_3_2 {
#
#         width: 4.75%;
#         height: 9.5%;
#         position: absolute;
#         left: 2.375%;
#         top: 34.916666666666664%;
#         font-family: monospace;
#         font-size: 2em;
#
#             transform: translate(-42.212508354668586%, -55.751913126026885%);
#             text-align: center;
#             color: #d04;
#             z-index: -1;
#             }
#
#         .text_0_4 {
#
#         width: 4.75%;
#         height: 9.5%;
#         position: absolute;
#         left: 2.375%;
#         top: 44.97222222222222%;
#         font-family: monospace;
#         font-size: 2em;
#
#         transform: translate(-50%, -50%);
#         transition: all 1s;
#         }
#
#         .text_0_4:hover {
#         transform: translate(-65.61643403138113%, 45.60985559479914%) rotate(0.2962299626327735turn);
#         }
#
#             .hidden_text_0_4_0 {
#
#         width: 4.75%;
#         height: 9.5%;
#         position: absolute;
#         left: 2.375%;
#         top: 44.97222222222222%;
#         font-family: monospace;
#         font-size: 2em;
#
#             transform: translate(-58.69500486738999%, -53.11019660808063%);
#             text-align: center;
#             color: #d04;
#             z-index: -1;
#             }
#
#             .hidden_text_0_4_1 {
#
#         width: 4.75%;
#         height: 9.5%;
#         position: absolute;
#         left: 2.375%;
#         top: 44.9722222222
