# %% [markdown]
# # Form Compositions

# %%
import random
import math

# %%
from IPython.display import display, HTML
def show_html(src):
    return display(HTML(src), metadata=dict(isolated=True))

# %%
html_template = """<!doctype html>
<html>
<head>
<meta charset="utf-8">
<title>{title}</title>
<style>
html {{ height: 32em; overflow: hidden; }}
</style>
</head>
<body>
{content}
</body>
</html>
"""

# %%
def p5map(n, fromMin, fromMax, toMin, toMax):
    return (n - fromMin) / (fromMax - fromMin) * (toMax - toMin) + toMin

# %% [markdown]
# ## Chaotic

# %%
elements = []
elements_num = 1000
for i in range(elements_num):
    x = random.random() * 100
    y = random.random() * 100
    checked = 'checked' if random.random() > 0.5 else ''
    element = f"<input type='checkbox' style='position: absolute; left: {x}%; top: {y}%;' {checked}/>"
    elements.append(element)
html_src = html_template.format(title="Checkboxes", content="".join(elements))

show_html(html_src)
# Out:
# <!doctype html>
# <html>
# <head>
# <meta charset="utf-8">
# <title>Checkboxes</title>
# <style>
# html { height: 32em; overflow: hidden; }
# </style>
# </head>
# <body>
# <input type='checkbox' style='position: absolute; left: 64.39372632300142%; top: 2.7127704148097176%;' checked/><input type='checkbox' style='position: absolute; left: 53.05754014225636%; top: 2.8793858058412503%;' /><input type='checkbox' style='position: absolute; left: 71.68409527963671%; top: 6.777023084087941%;' checked/><input type='checkbox' style='position: absolute; left: 44.0261019511725%; top: 13.876058974049243%;' checked/><input type='checkbox' style='position: absolute; left: 61.642559335318914%; top: 16.161949322190218%;' checked/><input type='checkbox' style='position: absolute; left: 44.29893036236038%; top: 41.19236162319996%;' /><input type='checkbox' style='position: absolute; left: 49.747606069140815%; top: 96.25931553895353%;' checked/><input type='checkbox' style='position: absolute; left: 21.110924457309753%; top: 78.66734367457285%;' checked/><input type='checkbox' style='position: absolute; left: 61.456217089406195%; top: 64.6856689356896%;' checked/><input type='checkbox' style='position: absolute; left: 72.73061821156872%; top: 5.703528041694883%;' checked/><input type='checkbox' style='position: absolute; left: 82.29572899683207%; top: 20.092907249233583%;' /><input type='checkbox' style='position: absolute; left: 62.515694526190266%; top: 78.53224174910038%;' checked/><input type='checkbox' style='position: absolute; left: 89.0175002930041%; top: 42.40973175392847%;' /><input type='checkbox' style='position: absolute; left: 55.94151364936831%; top: 70.1979807450717%;' checked/><input type='checkbox' style='position: absolute; left: 0.03330038068981578%; top: 68.14797427518175%;' checked/><input type='checkbox' style='position: absolute; left: 40.809182270009394%; top: 81.4176067554628%;' /><input type='checkbox' style='position: absolute; left: 65.25105466870953%; top: 77.49518145417376%;' /><input type='checkbox' style='position: absolute; left: 11.36913635271114%; top: 37.309972049210536%;' checked/><input type='checkbox' style='position: absolute; left: 38.53548386905411%; top: 61.90734894846608%;' checked/><input type='checkbox' style='position: absolute; left: 57.859001138826486%; top: 82.59923997583783%;' /><input type='checkbox' style='position: absolute; left: 66.34919717379137%; top: 51.49645040046228%;' checked/><input type='checkbox' style='position: absolute; left: 41.56772221746431%; top: 33.668609767654075%;' /><input type='checkbox' style='position: absolute; left: 85.80007344480754%; top: 75.4947794935785%;' checked/><input type='checkbox' style='position: absolute; left: 26.315662265984585%; top: 37.15953330614994%;' /><input type='checkbox' style='position: absolute; left: 97.08342914565056%; top: 28.369217078113774%;' checked/><input type='checkbox' style='position: absolute; left: 34.078623612243305%; top: 64.38230731081082%;' checked/><input type='checkbox' style='position: absolute; left: 90.15280390722783%; top: 90.47670869697131%;' /><input type='checkbox' style='position: absolute; left: 51.8743827325047%; top: 2.046189360540762%;' /><input type='checkbox' style='position: absolute; left: 92.32388274743238%; top: 29.932768952761325%;' checked/><input type='checkbox' style='position: absolute; left: 49.11651662159295%; top: 19.17148803799452%;' /><input type='checkbox' style='position: absolute; left: 18.876479111625777%; top: 71.03313026356145%;' checked/><input type='checkbox' style='position: absolute; left: 58.96537257319204%; top: 60.39844664606711%;' checked/><input type='checkbox' style='position: absolute; left: 78.91337138505602%; top: 33.978847515449694%;' checked/><input type='checkbox' style='position: absolute; left: 38.73889787594802%; top: 44.48058545007053%;' checked/><input type='checkbox' style='position: absolute; left: 78.47936472520746%; top: 97.49387768025007%;' checked/><input type='checkbox' style='position: absolute; left: 77.60105192518924%; top: 77.74405072206454%;' /><input type='checkbox' style='position: absolute; left: 44.84654243294581%; top: ...

# %% [markdown]
# ## Circular

# %%
elements = []
elements_num = 1000
radius = 40
button_text = '免费比特币'
for i in range(elements_num):
    progress = i / elements_num
    angle = progress * math.tau
    x = math.cos(angle) * radius + 50
    y = math.sin(angle) * radius + 50
    element = f"<button style='position: absolute; left: {x}%; top: {y}%; transform: translate(-50%, -50%);'>{button_text}</button>"
    elements.append(element)
html_src = html_template.format(title="Free bitcoins", content="".join(elements))

show_html(html_src)
# Out:
# <!doctype html>
# <html>
# <head>
# <meta charset="utf-8">
# <title>Free bitcoins</title>
# <style>
# html { height: 32em; overflow: hidden; }
# </style>
# </head>
# <body>
# <button style='position: absolute; left: 90.0%; top: 50.0%; transform: translate(-50%, -50%);'>免费比特币</button><button style='position: absolute; left: 89.99921043424548%; top: 50.25132575862236%; transform: translate(-50%, -50%);'>免费比特币</button><button style='position: absolute; left: 89.99684176815265%; top: 50.502641595334104%; transform: translate(-50%, -50%);'>免费比特币</button><button style='position: absolute; left: 89.99289409523236%; top: 50.753937588616324%; transform: translate(-50%, -50%);'>免费比特币</button><button style='position: absolute; left: 89.987367571332%; top: 51.0052038177335%; transform: translate(-50%, -50%);'>免费比特币</button><button style='position: absolute; left: 89.98026241462927%; top: 51.25643036312513%; transform: translate(-50%, -50%);'>免费比特币</button><button style='position: absolute; left: 89.97157890562357%; top: 51.50760730679738%; transform: translate(-50%, -50%);'>免费比特币</button><button style='position: absolute; left: 89.96131738712498%; top: 51.7587247327146%; transform: translate(-50%, -50%);'>免费比特币</button><button style='position: absolute; left: 89.9494782642407%; top: 52.00977272719078%; transform: translate(-50%, -50%);'>免费比特币</button><button style='position: absolute; left: 89.936062004359%; top: 52.26074137928098%; transform: translate(-50%, -50%);'>免费比特币</button><button style='position: absolute; left: 89.92106913713087%; top: 52.51162078117253%; transform: translate(-50%, -50%);'>免费比特币</button><button style='position: absolute; left: 89.904500254449%; top: 52.76240102857623%; transform: translate(-50%, -50%);'>免费比特币</button><button style='position: absolute; left: 89.88635601042455%; top: 53.01307222111731%; transform: translate(-50%, -50%);'>免费比特币</button><button style='position: absolute; left: 89.8666371213612%; top: 53.2636244627263%; transform: translate(-50%, -50%);'>免费比特币</button><button style='position: absolute; left: 89.8453443657269%; top: 53.51404786202973%; transform: translate(-50%, -50%);'>免费比特币</button><button style='position: absolute; left: 89.8224785841232%; top: 53.764332532740575%; transform: translate(-50%, -50%);'>免费比特币</button><button style='position: absolute; left: 89.79804067925201%; top: 54.014468594048594%; transform: translate(-50%, -50%);'>免费比特币</button><button style='position: absolute; left: 89.77203161587995%; top: 54.2644461710104%; transform: translate(-50%, -50%);'>免费比特币</button><button style='position: absolute; left: 89.74445242080034%; top: 54.51425539493927%; transform: translate(-50%, -50%);'>免费比特币</button><button style='position: absolute; left: 89.71530418279255%; top: 54.763886403794785%; transform: translate(-50%, -50%);'>免费比特币</button><button style='position: absolute; left: 89.68458805257912%; top: 55.01332934257217%; transform: translate(-50%, -50%);'>免费比特币</button><button style='position: absolute; left: 89.65230524278027%; top: 55.2625743636913%; transform: translate(-50%, -50%);'>免费比特币</button><button style='position: absolute; left: 89.61845702786604%; top: 55.51161162738552%; transform: translate(-50%, -50%);'>免费比特币</button><button style='position: absolute; left: 89.58304474410605%; top: 55.76043130209008%; transform: translate(-50%, -50%);'>免费比特币</button><button style='position: absolute; left: 89.54606978951657%; top: 56.00902356483029%; transform: translate(-50%, -50%);'>免费比特币</button><button style='position: absolute; left: 89.50753362380551%; top: 56.25737860160923%; transform: translate(-50%, -50%);'>免费比特币</button><button style='position: absolute; left: 89.46743776831472%; top: 56.50548660779534%; transform: translate(-50%, -50%);'>免费比特币</button><button style='position: absolute; left: 89.42578380595992%; top: 56.753337788509356%; transform: translate(-50%, -50%);'>免费比特币</button><button style='position: absolute; left: 89.38257338116821%; top: 57.00092235901104%; transform: translate(-50%, -50%);'>免费比特币</button><button style='position: absolute; left: 89.3378081998132%; top: 57.24823054508549%; transform: translate(-50%, -50%);'> ...

# %% [markdown]
# ## Wavy

# %%
elements = []
elements_num = 1000
min_radius = 30
max_radius = 40
button_text = '点此链接'
periods_num = 10
for i in range(elements_num):
    progress = i / elements_num
    angle = progress * math.tau
    radius = p5map(math.sin(angle * periods_num), -1, 1, min_radius, max_radius)
    x = math.cos(angle) * radius + 50
    y = math.sin(angle) * radius + 50
    element = f"<button style='position: absolute; left: {x}%; top: {y}%; transform: translate(-50%, -50%);'>{button_text}</button>"
    elements.append(element)
html_src = html_template.format(title="Click here", content="".join(elements))

show_html(html_src)
# Out:
# <!doctype html>
# <html>
# <head>
# <meta charset="utf-8">
# <title>Click here</title>
# <style>
# html { height: 32em; overflow: hidden; }
# </style>
# </head>
# <body>
# <button style='position: absolute; left: 85.0%; top: 50.0%; transform: translate(-50%, -50%);'>点此链接</button><button style='position: absolute; left: 85.31325553045588%; top: 50.22188264816394%; transform: translate(-50%, -50%);'>点此链接</button><button style='position: absolute; left: 85.62385323602885%; top: 50.447686107975734%; transform: translate(-50%, -50%);'>点此链接</button><button style='position: absolute; left: 85.93052246703485%; top: 50.6773546170981%; transform: translate(-50%, -50%);'>点此链接</button><button style='position: absolute; left: 86.23200336608227%; top: 50.91080134351804%; transform: translate(-50%, -50%);'>点此链接</button><button style='position: absolute; left: 86.52705217851191%; top: 51.14790885954128%; transform: translate(-50%, -50%);'>点此链接</button><button style='position: absolute; left: 86.81444649301224%; top: 51.38852980162758%; transform: translate(-50%, -50%);'>点此链接</button><button style='position: absolute; left: 87.09299038962149%; top: 51.63248771246942%; transform: translate(-50%, -50%);'>点此链接</button><button style='position: absolute; left: 87.36151947274118%; top: 51.87957806072113%; transform: translate(-50%, -50%);'>点此链接</button><button style='position: absolute; left: 87.6189057672989%; top: 52.12956943281292%; transform: translate(-50%, -50%);'>点此链接</button><button style='position: absolute; left: 87.86406245680871%; top: 52.382204890341534%; transform: translate(-50%, -50%);'>点此链接</button><button style='position: absolute; left: 88.0959484427827%; top: 52.637203485619324%; transform: translate(-50%, -50%);'>点此链接</button><button style='position: absolute; left: 88.31357270574367%; top: 52.89426192709264%; transform: translate(-50%, -50%);'>点此链接</button><button style='position: absolute; left: 88.51599844897432%; top: 53.15305638551208%; transform: translate(-50%, -50%);'>点此链接</button><button style='position: absolute; left: 88.70234700710532%; top: 53.41324443095624%; transform: translate(-50%, -50%);'>点此链接</button><button style='position: absolute; left: 88.87180150269381%; top: 53.6744670900812%; transform: translate(-50%, -50%);'>点此链接</button><button style='position: absolute; left: 89.0236102350652%; top: 53.93635101229328%; transform: translate(-50%, -50%);'>点此链接</button><button style='position: absolute; left: 89.15708978688389%; top: 54.19851073292708%; transform: translate(-50%, -50%);'>点此链接</button><button style='position: absolute; left: 89.27162783517389%; top: 54.46055102095708%; transform: translate(-50%, -50%);'>点此链接</button><button style='position: absolute; left: 89.36668565482596%; top: 54.72206929828183%; transform: translate(-50%, -50%);'>点此链接</button><button style='position: absolute; left: 89.44180030399349%; top: 54.98265811719902%; transform: translate(-50%, -50%);'>点此链接</button><button style='position: absolute; left: 89.49658648219392%; top: 55.241907682337214%; transform: translate(-50%, -50%);'>点此链接</button><button style='position: absolute; left: 89.5307380533847%; top: 55.499408403030934%; transform: translate(-50%, -50%);'>点此链接</button><button style='position: absolute; left: 89.54402922776983%; top: 55.754753461918284%; transform: translate(-50%, -50%);'>点此链接</button><button style='position: absolute; left: 89.5363153976054%; top: 56.007541385408494%; transform: translate(-50%, -50%);'>点此链接</button><button style='position: absolute; left: 89.50753362380551%; top: 56.25737860160923%; transform: translate(-50%, -50%);'>点此链接</button><button style='position: absolute; left: 89.45770277169507%; top: 56.503881971322414%; transform: translate(-50%, -50%);'>点此链接</button><button style='position: absolute; left: 89.38692329580732%; top: 56.74668127781103%; transform: translate(-50%, -50%);'>点此链接</button><button style='position: absolute; left: 89.29537667517326%; top: 56.98542166120941%; transform: translate(-50%, -50%);'>点此链接</button><button style='position: absolute; left: 89.1833245020924%; top: 57.21976598369331%; transform: translate(-50%, -50%);'>点此链接</button><butto ...

# %% [markdown]
# ## Flowery

# %%
elements = []
elements_num = 1000
min_radius = -40
max_radius = 40
button_text = '老天爷呀'
periods_num = 8
for i in range(elements_num):
    progress = i / elements_num
    angle = progress * math.tau
    radius = p5map(math.sin(angle * periods_num), -1, 1, min_radius, max_radius)
    x = math.cos(angle) * radius + 50
    y = math.sin(angle) * radius + 50
    element = f"<button style='position: absolute; left: {x}%; top: {y}%; transform: translate(-50%, -50%);'>{button_text}</button>"
    elements.append(element)
html_src = html_template.format(title="OMG", content="".join(elements))

show_html(html_src)
# Out:
# <!doctype html>
# <html>
# <head>
# <meta charset="utf-8">
# <title>OMG</title>
# <style>
# html { height: 32em; overflow: hidden; }
# </style>
# </head>
# <body>
# <button style='position: absolute; left: 50.0%; top: 50.0%; transform: translate(-50%, -50%);'>老天爷呀</button><button style='position: absolute; left: 52.00973305599779%; top: 50.012627691382995%; transform: translate(-50%, -50%);'>老天爷呀</button><button style='position: absolute; left: 54.0141516284845%; top: 50.05044597246328%; transform: translate(-50%, -50%);'>老天爷呀</button><button style='position: absolute; left: 56.00795607610033%; top: 50.11326071841017%; transform: translate(-50%, -50%);'>老天爷呀</button><button style='position: absolute; left: 57.98587639849314%; top: 50.200749234852566%; transform: translate(-50%, -50%);'>老天爷呀</button><button style='position: absolute; left: 59.94268694871544%; top: 50.31246152523609%; transform: translate(-50%, -50%);'>老天爷呀</button><button style='position: absolute; left: 61.873221016257666%; top: 50.447822058808185%; transform: translate(-50%, -50%);'>老天爷呀</button><button style='position: absolute; left: 63.77238523820341%; top: 50.60613203294208%; transform: translate(-50%, -50%);'>老天爷呀</button><button style='position: absolute; left: 65.635173796509%; top: 50.78657212175006%; transform: translate(-50%, -50%);'>老天爷呀</button><button style='position: absolute; left: 67.45668236005457%; top: 50.988205701203896%; transform: translate(-50%, -50%);'>老天爷呀</button><button style='position: absolute; left: 69.23212173088137%; top: 51.20998253928009%; transform: translate(-50%, -50%);'>老天爷呀</button><button style='position: absolute; left: 70.95683115492068%; top: 51.45074293798722%; transform: translate(-50%, -50%);'>老天爷呀</button><button style='position: absolute; left: 72.62629125852922%; top: 51.70922231251624%; transform: translate(-50%, -50%);'>老天爷呀</button><button style='position: absolute; left: 74.23613657327192%; top: 51.9840561911886%; transform: translate(-50%, -50%);'>老天爷呀</button><button style='position: absolute; left: 75.78216761263104%; top: 52.273785618366695%; transform: translate(-50%, -50%);'>老天爷呀</button><button style='position: absolute; left: 77.26036246566872%; top: 52.57686294104077%; transform: translate(-50%, -50%);'>老天爷呀</button><button style='position: absolute; left: 78.66688787412126%; top: 52.89165795842227%; transform: translate(-50%, -50%);'>老天爷呀</button><button style='position: absolute; left: 79.99810976095742%; top: 53.21646441255938%; transform: translate(-50%, -50%);'>老天爷呀</button><button style='position: absolute; left: 81.25060318007954%; top: 53.54950679675107%; transform: translate(-50%, -50%);'>老天爷呀</button><button style='position: absolute; left: 82.42116165858593%; top: 53.88894745737562%; transform: translate(-50%, -50%);'>老天爷呀</button><button style='position: absolute; left: 83.50680590483617%; top: 54.23289396367234%; transform: translate(-50%, -50%);'>老天爷呀</button><button style='position: absolute; left: 84.50479185746465%; top: 54.57940671902448%; transform: translate(-50%, -50%);'>老天爷呀</button><button style='position: absolute; left: 85.41261805246342%; top: 54.92650678639094%; transform: translate(-50%, -50%);'>老天爷呀</button><button style='position: absolute; left: 86.22803228750185%; top: 55.27218389972717%; transform: translate(-50%, -50%);'>老天爷呀</button><button style='position: absolute; left: 86.94903756475439%; top: 55.61440463252474%; transform: translate(-50%, -50%);'>老天爷呀</button><button style='position: absolute; left: 87.57389729567012%; top: 55.95112069398632%; transform: translate(-50%, -50%);'>老天爷呀</button><button style='position: absolute; left: 88.10113975332592%; top: 56.280277322841386%; transform: translate(-50%, -50%);'>老天爷呀</button><button style='position: absolute; left: 88.52956176025573%; top: 56.59982174839871%; transform: translate(-50%, -50%);'>老天爷呀</button><button style='position: absolute; left: 88.8582316019336%; top: 56.90771168812678%; transform: translate(-50%, -50%);'>老天爷呀</button><button style='position: absolute; left: 89.08649115840112%; top: 57.201923850853554%; transform: translate(-50%, -50%);'>老天爷呀</button><bu ...

# %% [markdown]
# ## Lissajous

# %%
elements = []
elements_num = 1024
min_radius = 30
max_radius = 50
span_texts = ['为什么','为啥','凭什么','谁说的','我不信']
font_size = 10
periods_num = 1
for i in range(elements_num):
    span_text = random.choice(span_texts)
    progress = i / elements_num
    angle = progress * math.tau
    radius = p5map(math.sin(angle * periods_num), -1, 1, min_radius, max_radius)
    x = math.cos(angle * 1) * radius + 50
    y = math.sin(angle * 23) * radius + 50
    element = f"<button style='position: absolute; left: {x}%; top: {y}%; font-family:monospace; font-size: {font_size}; transform: translate(-50%, -50%)'>{span_text}</button>"
    elements.append(element)
html_src = html_template.format(title="Why", content="".join(elements))

show_html(html_src)
# Out:
# <!doctype html>
# <html>
# <head>
# <meta charset="utf-8">
# <title>Why</title>
# <style>
# html { height: 32em; overflow: hidden; }
# </style>
# </head>
# <body>
# <button style='position: absolute; left: 90.0%; top: 50.0%; font-family:monospace; font-size: 10; transform: translate(-50%, -50%)'>凭什么</button><button style='position: absolute; left: 90.06060470273263%; top: 55.63496020062897%; font-family:monospace; font-size: 10; transform: translate(-50%, -50%)'>凭什么</button><button style='position: absolute; left: 90.11969421618033%; top: 61.17496622571828%; font-family:monospace; font-size: 10; transform: translate(-50%, -50%)'>为啥</button><button style='position: absolute; left: 90.17725938653973%; top: 66.50934963514922%; font-family:monospace; font-size: 10; transform: translate(-50%, -50%)'>凭什么</button><button style='position: absolute; left: 90.23329111948526%; top: 71.53119978397253%; font-family:monospace; font-size: 10; transform: translate(-50%, -50%)'>谁说的</button><button style='position: absolute; left: 90.28778038155477%; top: 76.13950655697018%; font-family:monospace; font-size: 10; transform: translate(-50%, -50%)'>为什么</button><button style='position: absolute; left: 90.34071820153233%; top: 80.24119208380547%; font-family:monospace; font-size: 10; transform: translate(-50%, -50%)'>为啥</button><button style='position: absolute; left: 90.392095671828%; top: 83.75299056577128%; font-family:monospace; font-size: 10; transform: translate(-50%, -50%)'>为什么</button><button style='position: absolute; left: 90.44190394985469%; top: 86.60313824724227%; font-family:monospace; font-size: 10; transform: translate(-50%, -50%)'>凭什么</button><button style='position: absolute; left: 90.4901342594012%; top: 88.73283923396168%; font-family:monospace; font-size: 10; transform: translate(-50%, -50%)'>我不信</button><button style='position: absolute; left: 90.53677789200205%; top: 90.09747722545089%; font-family:monospace; font-size: 10; transform: translate(-50%, -50%)'>凭什么</button><button style='position: absolute; left: 90.58182620830328%; top: 90.66754820519222%; font-family:monospace; font-size: 10; transform: translate(-50%, -50%)'>为什么</button><button style='position: absolute; left: 90.62527063942443%; top: 90.42929462239195%; font-family:monospace; font-size: 10; transform: translate(-50%, -50%)'>为啥</button><button style='position: absolute; left: 90.66710268831594%; top: 89.38502749509297%; font-family:monospace; font-size: 10; transform: translate(-50%, -50%)'>为啥</button><button style='position: absolute; left: 90.70731393111262%; top: 87.55312904973783%; font-family:monospace; font-size: 10; transform: translate(-50%, -50%)'>凭什么</button><button style='position: absolute; left: 90.7458960184821%; top: 84.96773486438556%; font-family:monospace; font-size: 10; transform: translate(-50%, -50%)'>为啥</button><button style='position: absolute; left: 90.78284067696852%; top: 81.67810087534421%; font-family:monospace; font-size: 10; transform: translate(-50%, -50%)'>谁说的</button><button style='position: absolute; left: 90.81813971033131%; top: 77.74766691246501%; font-family:monospace; font-size: 10; transform: translate(-50%, -50%)'>为啥</button><button style='position: absolute; left: 90.85178500087859%; top: 73.25283452055389%; font-family:monospace; font-size: 10; transform: translate(-50%, -50%)'>为什么</button><button style='position: absolute; left: 90.88376851079514%; top: 68.28148258095808%; font-family:monospace; font-size: 10; transform: translate(-50%, -50%)'>凭什么</button><button style='position: absolute; left: 90.91408228346472%; top: 62.93124955235459%; font-family:monospace; font-size: 10; transform: translate(-50%, -50%)'>为什么</button><button style='position: absolute; left: 90.94271844478655%; top: 57.30761589574085%; font-family:monospace; font-size: 10; transform: translate(-50%, -50%)'>为啥</button><button style='position: absolute; left: 90.9696692044857%; top: 51.52182433907065%; font-family:monospace; font-size: 10; transform: translate(-50%, -50%)'>为啥</button><button style='position: absolute; left: 90.99492685741714%; top: 45.6886789881488%; font-family:monospace; font-size: 10; transf ...

# %%
elements = []
elements_num = 1024
min_radius = 30
max_radius = 50
span_texts = ['为什么','为啥','凭什么','谁说的','我不信']
font_size = 10
periods_num = 1
span_width = '4em';
for i in range(elements_num):
    span_text = random.choice(span_texts)
    progress = i / elements_num
    angle = progress * math.tau
    radius = p5map(math.sin(angle * periods_num), -1, 1, min_radius, max_radius)
    x = math.cos(angle * 3) * radius + 50
    y = math.sin(angle * 11) * radius + 50
    element = f"<input value='{span_text}' style='width: {span_width}; position: absolute; left: {x}%; top: {y}%; font-family:monospace; font-size: {font_size}; transform: translate(-50%, -50%);' onMouseOver='this.style.fontSize=\'2px\''>"
    elements.append(element)
html_src = html_template.format(title="Why", content="".join(elements))

show_html(html_src)
# Out:
# <!doctype html>
# <html>
# <head>
# <meta charset="utf-8">
# <title>Why</title>
# <style>
# html { height: 32em; overflow: hidden; }
# </style>
# </head>
# <body>
# <input value='我不信' style='width: 4em; position: absolute; left: 90.0%; top: 50.0%; font-family:monospace; font-size: 10; transform: translate(-50%, -50%);' onMouseOver='this.style.fontSize='2px''><input value='凭什么' style='width: 4em; position: absolute; left: 90.0545717230189%; top: 52.70189506365386%; font-family:monospace; font-size: 10; transform: translate(-50%, -50%);' onMouseOver='this.style.fontSize='2px''><input value='为什么' style='width: 4em; position: absolute; left: 90.09552761255651%; top: 55.39974346345469%; font-family:monospace; font-size: 10; transform: translate(-50%, -50%);' onMouseOver='this.style.fontSize='2px''><input value='谁说的' style='width: 4em; position: absolute; left: 90.12280992622334%; top: 58.08120218064712%; font-family:monospace; font-size: 10; transform: translate(-50%, -50%);' onMouseOver='this.style.fontSize='2px''><input value='为什么' style='width: 4em; position: absolute; left: 90.13636559715832%; top: 60.73396488630761%; font-family:monospace; font-size: 10; transform: translate(-50%, -50%);' onMouseOver='this.style.fontSize='2px''><input value='为什么' style='width: 4em; position: absolute; left: 90.13614627319143%; top: 63.345818437992335%; font-family:monospace; font-size: 10; transform: translate(-50%, -50%);' onMouseOver='this.style.fontSize='2px''><input value='凭什么' style='width: 4em; position: absolute; left: 90.12210835437271%; top: 65.9046991309984%; font-family:monospace; font-size: 10; transform: translate(-50%, -50%);' onMouseOver='this.style.fontSize='2px''><input value='谁说的' style='width: 4em; position: absolute; left: 90.09421302884328%; top: 68.3987484449628%; font-family:monospace; font-size: 10; transform: translate(-50%, -50%);' onMouseOver='this.style.fontSize='2px''><input value='我不信' style='width: 4em; position: absolute; left: 90.05242630702408%; top: 70.8163680279579%; font-family:monospace; font-size: 10; transform: translate(-50%, -50%);' onMouseOver='this.style.fontSize='2px''><input value='我不信' style='width: 4em; position: absolute; left: 89.99671905409889%; top: 73.14627366287199%; font-family:monospace; font-size: 10; transform: translate(-50%, -50%);' onMouseOver='this.style.fontSize='2px''><input value='凭什么' style='width: 4em; position: absolute; left: 89.92706702076889%; top: 75.37754796467857%; font-family:monospace; font-size: 10; transform: translate(-50%, -50%);' onMouseOver='this.style.fontSize='2px''><input value='我不信' style='width: 4em; position: absolute; left: 89.84345087225648%; top: 77.49969156218778%; font-family:monospace; font-size: 10; transform: translate(-50%, -50%);' onMouseOver='this.style.fontSize='2px''><input value='为啥' style='width: 4em; position: absolute; left: 89.74585621553665%; top: 79.50267252401525%; font-family:monospace; font-size: 10; transform: translate(-50%, -50%);' onMouseOver='this.style.fontSize='2px''><input value='为啥' style='width: 4em; position: absolute; left: 89.63427362477522%; top: 81.37697379577882%; font-family:monospace; font-size: 10; transform: translate(-50%, -50%);' onMouseOver='this.style.fontSize='2px''><input value='为什么' style='width: 4em; position: absolute; left: 89.50869866495367%; top: 83.11363842390656%; font-family:monospace; font-size: 10; transform: translate(-50%, -50%);' onMouseOver='this.style.fontSize='2px''><input value='凭什么' style='width: 4em; position: absolute; left: 89.36913191366091%; top: 84.70431235088049%; font-family:monospace; font-size: 10; transform: translate(-50%, -50%);' onMouseOver='this.style.fontSize='2px''><input value='为什么' style='width: 4em; position: absolute; left: 89.21557898103316%; top: 86.14128457720676%; font-family:monospace; font-size: 10; transform: translate(-50%, -50%);' onMouseOver='this.style.fontSize='2px''><input value='为啥' style='width: 4em; position: absolute; left: 89.04805052782419%; top: 87.41752449685133%; font-family:monospace; font-size: 10; transform: translate(-50%, -50%);' onMouseOver='this.style.fontSize='2px''><input value='谁说的' style='width: 4em ...
